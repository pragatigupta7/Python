# %%
from dputils.scrape import Scraper, Tag

# %%
url = 'https://www.flipkart.com/motorola-edge-50-pro-5g-68w-charger-black-beauty-256-gb/p/itmb3f6625c5c896?pid=MOBGXFXYDG8YRZU4&lid=LSTMOBGXFXYDG8YRZU4SAX9WW&marketplace=FLIPKART&store=tyy%2F4io&srno=b_1_1&otracker=browse&fm=organic&iid=ace38f80-151a-41b0-a079-b620b88b8ec9.MOBGXFXYDG8YRZU4.SEARCH&ppt=hp&ppn=homepage&ssid=vj43l0oe680000001721542596100'
s1 = Scraper(url)

# %%
heading= Tag('h1', cls='_6EBuvT')
price = Tag(cls='Nx9bqj CxhGGd')
desc = Tag(cls='U+9u4y')
review = Tag(cls='RcXBOT')
results = s1.get_data_from_page(heading=heading, price=price, desc=desc, review=review)

# %% [markdown]
# multiple items from a single page

# %%
items = Tag(cls='cPHDOP col-12-12')
url = "https://www.flipkart.com/tyy/4io/~cs-33irmtdz82/pr?sid=tyy%2C4io&collection-tab-name=Moto+Edge+50+pro+5g&param=279892&ctx=..."
s2 = Scraper(url)
results = s2.get_repeating_date_from_page(
    target = Tag('body'),
    items = items,
    title = Tag(cls='KzDlHZ'),
    price = Tag(cls='Nx9bqj _4b5DiR'),
    ratings = Tag('span', cls='Wphh3N')
)

# %%
import pandas as pd
pd.DataFrame(results)
# Out:
#                                                 title    price  \
# 0                                                None     None
# 1                                                None     None
# 2   Motorola Edge 50 Pro 5G with 68W Charger (Luxe...  ₹29,999
# 3   Motorola Edge 50 Pro 5G with 68W Charger (Blac...  ₹29,999
# 4   Motorola Edge 50 Pro 5G with 125W Charger (Bla...  ₹34,999
# 5   Motorola Edge 50 Pro 5G with 125W Charger (Lux...  ₹34,999
# 6   Motorola Edge 50 Pro 5G with 125W Charger (Van...  ₹34,999
# 7   Motorola Edge 50 Pro 5G with 68W Charger (Moon...  ₹29,999
# 8   Motorola Edge 50 Pro 5G with 68W Charger (Vani...  ₹29,999
# 9   Motorola Edge 50 Pro 5G with 125W Charger (Moo...  ₹34,999
# 10                                               None     None
# 11                                               None     None
#
#                            ratings
# 0                             None
# 1                             None
# 2   19,628 Ratings & 1,737 Reviews
# 3   19,628 Ratings & 1,737 Reviews
# 4      7,036 Ratings & 594 Reviews
# 5      7,036 Ratings & 594 Reviews
# 6      7,036 Ratings & 594 Reviews
# 7   19,628 Ratings & 1,737 Reviews
# 8   19,628 Ratings & 1,737 Reviews
# 9      7,036 Ratings & 594 Reviews
# 10                            None
# 11                            None

# %%
items = Tag(cls='s-result-item')
title = Tag('span', cls='a-size-base-plus a-color-base a-text-normal')
url ='https://www.amazon.in/s?k=shoes&crid=2OAOAMZS2EVJY&sprefix=shoe%2Caps%2C306&ref=nb_sb_noss_1'
s3 = Scraper(url)
results = s3.get_repeating_date_from_page(
    target = Tag('body'),
    items = items,
    title = title,
    brand = Tag('h2', cls='a-size-mini s-line-clamp-1')
)
pd.DataFrame(results).dropna()
# Out:
#                                                 title        brand
# 2   Summit Sports Running Walking Gym Shoes for Me...       Campus
# 3           Men's STUSSYY (MEMORY TECH) Running Shoes   OFF LIMITS
# 4                           Mens 6070-03 Running Shoe     Centrino
# 5                                  Men's Running Shoe  Bacca Bucci
# 6   Exclusive Trendy Sports Running Shoes | Casual...       BRUTON
# ..                                                ...          ...
# 71  Summit Sports Running Walking Gym Shoes for Me...       Campus
# 72  Xaven Running, Walking, and Workout Sports Sho...       Campus
# 73  Men's Dakota Walking Shoes Non-Slip Breathable...   OFF LIMITS
# 74  Orthopedic & Diabetic Shoes Breathable Soft So...   HEALTH FIT
# 75  Samurai Cushioned Running Training Fitness Wor...   OFF LIMITS
#
# [73 rows x 2 columns]

# %%
start = 1
term = 'shoes'
all_data = []
while True:
    url = f"https://www.amazon.in/s?k={term}&page={start}&crid=2OAOAMZS2EVJY&qid=1721544045&sprefix=shoe%2Caps%2C306&ref=sr_pg_2"
    sc = Scraper(url)
    results = sc.get_repeating_date_from_page(
        target = Tag('body'),
        items = items,
        title = title,
        brand = Tag('h2', cls='a-size-mini s-line-clamp-1')
    )
    if len(results) == 0:
        break
    all_data.extend(results)
    start += 1

df = pd.DataFrame(all_data).dropna()
df
# Out:
#                                                  title       brand
# 2    Summit Sports Running Walking Gym Shoes for Me...      Campus
# 3    Orthopedic & Diabetic Sports Shoes Breathable ...  HEALTH FIT
# 4            Men's STUSSYY (MEMORY TECH) Running Shoes  OFF LIMITS
# 5    Men's Thar-01 Sports Running,Walking & Gym Sho...       ASIAN
# 6    Lifestyle Sneaker Shoes for Men | Elegantly Ro...    Red Tape
# ..                                                 ...         ...
# 146  Wendigo Sports Shoes for Men | Perfect for Run...      Campus
# 147  Sports Shoes for Men |Latest Stylish Sports Sh...    Bersache
# 148  Running Shoes, Sports Shoes for Men||Memory Fo...    Aqualite
# 149  Men's DELIGHT Low-Top Casual Trendy Cushioned ...  FIELD CARE
# 150  Sports Socks for Men, Sole Terry/Towel Cushion...      ANCHOR
#
# [139 rows x 2 columns]

# %%
url='https://www.ndtv.com/latest/page-2'
news_scraper = Scraper(url)
items = Tag(cls='news_Itm')
img_src = Tag('img', output='src')
title = Tag('h2', cls='newsHdng')
post = Tag('span', cls='posted-by')
content = Tag('p', cls='newsCont')
target = Tag('body')
news_scraper.get_repeating_date_from_page(
    target = target, items=items, 
    image=img_src, title=title, 
    post=post, content=content
)
# Out:
# [{'image': 'https://c.ndtvimg.com/2024-07/6h8u1do8_byju-raveendran_625x300_22_July_24.jpg?im=FeatureCrop,algorithm=dnn,width=240,height=180',
#   'title': "Byju's Founder Faces Reckoning As Company's Valuation Drops To $2 Billion",
#   'post': 'Reuters   | Monday July 22, 2024, New Delhi                                                        \n                                                        ',
#   'content': 'Byju Raveendran, the mathematics whiz who soared from teacher to startup billionaire before his education technology company imploded this year, now faces his biggest test.'},
#  {'image': 'https://c.ndtvimg.com/2024-07/ct8fl9vg_south-african-police_625x300_22_July_24.jpeg',
#   'title': 'South African Police Uncover Multimillion-Dollar Meth Lab On Farm',
#   'post': '\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tEdited by Anjali Thakur  | Monday July 22, 2024                                                        \n                                                        ',
#   'content': 'The South African Police Service (SAPS) and the Directorate for Priority Crime Investigation, known as the Hawks, raided the property.'},
#  {'image': 'https://i.ndtvimg.com/i/2018-03/security-forces-kashmir-generic_650x400_51520188882.jpg',
#   'title': "Fresh Terror Attack After Army Chief's Visit Thwarted In Jammu's Rajouri",
#   'post': '\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tWritten by Nazir Masoodi  | Monday July 22, 2024, Rajouri/Jammu                                                        \n                                                        ',
#   'content': "The Indian Army repulsed a major attack in Jammu and Kashmir's Rajouri district this morning. A soldier was injured in the predawn attack at an army camp, suggest initial reports."},
#  {'image': None, 'title': None, 'post': None, 'content': None},
#  {'image': 'https://c.ndtvimg.com/2024-07/91k5o4i8_ab-de-villiers-and-babar-azam_625x300_21_July_24.jpg?im=FitAndFill,algorithm=dnn,width=240,height=180',
#   'title': "Not Rohit Sharma Or Virat Kohli: Babar Azam's 'Best Batter' Pick Leaves AB De Villiers Amused",
#   'post': 'NDTV Sports Desk   | Monday July 22, 2024                                                        \n                                                        ',
#   'content': 'Pakistan cricket team captain Babar Azam picked South Africa legend AB De Villiers as the best batter he has played against during his career.'},
#  {'image': 'https://c.ndtvimg.com/2024-07/67hfv6to_gautam-gambhir_640x480_10_July_24.jpg?im=FeatureCrop,algorithm=dnn,width=240,height=180',
#   'title': 'Gautam Gambhir Press Conference: 3 Big Questions India Head Coach Needs To Answer',
#   'post': 'NDTV Sports Desk   | Monday July 22, 2024                                                        \n                                                        ',
#   'content': 'India head coach Gautam Gambhir addresses media for the first time since replacing Rahul Dravid in the role.'},
#  {'image': 'https://c.ndtvimg.com/2024-07/kc1vpiog_umakant-soni_120x90_12_July_24.jpg',
#   'title': 'Opinion | A Viksit Bharat Will Need Viksit, Intelligent Villages Too',
#   'post': 'Umakant Soni   | Monday July 22, 2024                                                        \n                                                        ',
#   'content': 'Transforming both the ailing PSU and dormant villages with technology innovations of the "Viksit Village" will make the vision of Viksit Bharat real.'},
#  {'image': None, 'title': None, 'post': None, 'content': None},
#  {'image': 'https://c.ndtvimg.com/2024-07/5hctb05g_joe-biden_625x300_22_July_24.jpg?im=FeatureCrop,algorithm=dnn,width=240,height=180',
#   'title': 'Hours After Biden Drops Out, Kamala Harris Receives $46 Million Donation',
#   'post': 'Agence France-Presse   | Monday July 22, 2024, Washington                                                        \n                                                        ',
#   'content': 'Democratic fundraising group ActBlue said Sunday evening that it had seen its biggest single-day haul of the 2024 election after US President Joe Biden dropped out and endorsed Vice President Kamala Harris.'},
#  {'image': 'https://c.ndtvimg.com/2024-07/tt0ndfr8_gambhir-x_625x300_22_July_24.jpeg',
#   'title': "India Head Coach Gautam Gambhir's First Press Conference Live Streaming: When and Where To Watch?",
#   'post': 'NDTV Sports Desk   | Monday July 22, 2024                                                        \n                                                        ',
#   'content': "The Indian cricket team's upcoming tour to Sri Lanka will be the first assignment for newly-appointed head coach Gautam Gambhir."},
#  {'image': 'https://i.ndtvimg.com/i/2017-10/exam-result_650x400_51508568554.jpg?im=FeatureCrop,algorithm=dnn,width=240,height=180',
#   'title': 'West Bengal Primary TET Result 2024 To Be Released Soon',
#   'post': '\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tEdited by Lavkesh Singh  | Monday July 22, 2024                                                        \n                                                        ',
#   'content': 'WB Primary TET Result 2024: Candidates who have taken the exam can check and download their results by visiting the official site.'},
#  {'image': 'https://c.ndtvimg.com/2024-07/9g6gf9b8_ben-stokes-doppelganger-x-englandcricket_625x300_21_July_24.jpg?im=FeatureCrop,algorithm=dnn,width=240,height=180',
#   'title': "Watch: Ben Stokes' Priceless Reaction After Spotting His Doppelganger Leaves Everyone In Splits",
#   'post': 'NDTV Sports Desk   | Monday July 22, 2024                                                        \n                                                        ',
#   'content': "Ben Stokes gave a funny reaction after spotting his look-alike in the crowd during his team's second Test match against West Indies at Trent Bridge."},
#  {'image': 'https://c.ndtvimg.com/2023-09/j7rett2o_ruturaj-gaikwad-afp_625x300_28_September_23.jpg?im=FeatureCrop,algorithm=dnn,width=240,height=180',
#   'title': '"What Has He Done?": Ex-India Star Questions Ruturaj Gaikwad\'s Snub From Sri Lanka Tour',
#   'post': 'NDTV Sports Desk   | Monday July 22, 2024                                                        \n                                                        ',
#   'content': 'BCCI on July 18 announced the squads for the upcoming Sri Lanka tour. Among the surprise omissions was Ruturaj Gaikwad.'},
#  {'image': 'https://c.ndtvimg.com/2024-07/59v82oc8_trump_625x300_22_July_24.jpg?im=FeatureCrop,algorithm=dnn,width=240,height=180',
#   'title': '"Lies, Cheats, Rapes": Indian-Origin Billionaire vs Elon Musk Over Trump',
#   'post': '\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tEdited by Aditi Gautam  | Monday July 22, 2024                                                        \n                                                        ',
#   'content': 'Prominent Indian-American businessman Vinod Khosla and billionaire Elon Musk engaged in a war of words this morning after Joe Biden dropped out of the presidential race against Republican rival Donald Trump.'},
#  {'image': 'https://c.ndtvimg.com/2024-07/4gpd7pgo_hardik-pandya-x_625x300_17_July_24.jpeg?im=FeatureCrop,algorithm=dnn,width=240,height=180',
#   'title': '"Injustice" Calls Intensify As Hardik Pandya Gets Snubbed For T20I Captaincy',
#   'post': 'NDTV Sports Desk   | Monday July 22, 2024                                                        \n                                                        ',
#   'content': "Hardik Pandya's career has been on a roller-coaster over the last 6 months, with several twists and turns taking place."},
#  {'image': 'https://c.ndtvimg.com/2024-07/16tsc1a8_kamala-harris-afp_625x300_22_July_24.jpg?im=FeatureCrop,algorithm=dnn,width=240,height=180',
#   'title': "Kamala Harris, Trailblazer Eyeing America's Last Glass Ceiling",
#   'post': 'Agence France-Presse   | Monday July 22, 2024, Washington                                                        \n                                                        ',
#   'content': "For years Kamala Harris faced criticism that she was not up to the job of being a heartbeat away from the US presidency. Now, she finds herself feted by Democrats as their best hope to stop Donald Trump's comeback."},
#  {'image': 'https://c.ndtvimg.com/2024-07/r5eouhrg_joe-biden-new_625x300_22_July_24.jpeg?im=FeatureCrop,algorithm=dnn,width=240,height=180',
#   'title': "Republicans Call For Biden's Resignation, Democrats Hail Legacy",
#   'post': 'Agence France-Presse   | Monday July 22, 2024, Washington                                                        \n                                                        ',
#   'content': "Leading Democrats were quick to hail Joe Biden's legacy on Sunday after the US president's historic decision to end his reelection bid, while Republicans instead demanded his resignation."}]

# %% [markdown]
# # sqlalchemy -> ORM(object relational mapping)

# %%
from sqlalchemy import create_engine, Table,Column,Integer,String,DateTime
from sqlalchemy.orm import Session, declarative_base
from datetime import datetime

Base = declarative_base()

class News(Base):
    __tablename__ = 'news'
    id = Column(Integer,primary_key=True)#auto increment
    title = Column(String)
    content = Column(String)
    posted_by = Column(String)
    image = Column(String)
    created_at = Column(DateTime,default=datetime.now)#auto timestamp

engine= create_engine("sqlite:///news.sqlite",echo=True)    #echo true all insert vales is shown in output n false only show imp data
Base.metadata.create_all(engine)
# Out:
# 2024-07-22 10:27:49,391 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-22 10:27:49,391 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("news")
# 2024-07-22 10:27:49,391 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-22 10:27:49,397 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("news")
# 2024-07-22 10:27:49,397 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-22 10:27:49,397 INFO sqlalchemy.engine.Engine
# CREATE TABLE news (
# 	id INTEGER NOT NULL,
# 	title VARCHAR,
# 	content VARCHAR,
# 	posted_by VARCHAR,
# 	image VARCHAR,
# 	created_at DATETIME,
# 	PRIMARY KEY (id)
# )
#
#
# 2024-07-22 10:27:49,397 INFO sqlalchemy.engine.Engine [no key 0.00171s] ()
# 2024-07-22 10:27:49,427 INFO sqlalchemy.engine.Engine COMMIT

# %%
from dputils.scrape import Scraper, Tag
url='https://www.ndtv.com/latest/page-2'
news_scraper = Scraper(url)
items = Tag(cls='news_Itm')
img_src = Tag('img', output='src')
title = Tag('h2', cls='newsHdng')
post = Tag('span', cls='posted-by')
content = Tag('p', cls='newsCont')
target = Tag('body')
out = news_scraper.get_repeating_date_from_page(
    target = target, items=items, 
    image=img_src, title=title, 
    post=post, content=content
)
db = Session(engine)
for entry in out:
    try:
        db.add(News(
        title=entry['title'],
        content=entry['content'],
        posted_by = entry['post'],
        image = entry['image']
        ))
    except Exception as e:   # error ko skip
        print(e)

db.commit()  #save
db.close()    #close
# Out:
# 2024-07-22 10:49:44,397 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-22 10:49:44,404 INFO sqlalchemy.engine.Engine INSERT INTO news (title, content, posted_by, image, created_at) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2024-07-22 10:49:44,406 INFO sqlalchemy.engine.Engine [cached since 386.4s ago (insertmanyvalues) 1/17 (ordered; batch not supported)] ('Gautam Gambhir Press Conference Live Updates: "My Relationship With Virat Not For TRPs"', 'Gautam Gambhir Press Conference Live: As the head coach of the Indian team, Gautam Gambhir speaks to media in Mumbai, with chief select Ajit Agarkar beside him.', 'NDTV Sports Desk   | Monday July 22, 2024                                                        \n                                                        ', 'https://c.ndtvimg.com/2024-07/2pvlbrmo_gambhir_625x300_22_July_24.jpg?im=FitAndFill,algorithm=dnn,width=240,height=180', '2024-07-22 10:49:44.404560')
# 2024-07-22 10:49:44,419 INFO sqlalchemy.engine.Engine INSERT INTO news (title, content, posted_by, image, created_at) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2024-07-22 10:49:44,421 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/17 (ordered; batch not supported)] ("Byju's Founder Faces Reckoning As Company's Valuation Drops To $2 Billion", 'Byju Raveendran, the mathematics whiz who soared from teacher to startup billionaire before his education technology company imploded this year, now faces his biggest test.', 'Reuters   | Monday July 22, 2024, New Delhi                                                        \n                                                        ', 'https://c.ndtvimg.com/2024-07/6h8u1do8_byju-raveendran_625x300_22_July_24.jpg?im=FeatureCrop,algorithm=dnn,width=240,height=180', '2024-07-22 10:49:44.404560')
# 2024-07-22 10:49:44,421 INFO sqlalchemy.engine.Engine INSERT INTO news (title, content, posted_by, image, created_at) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2024-07-22 10:49:44,423 INFO sqlalchemy.engine.Engine [insertmanyvalues 3/17 (ordered; batch not supported)] ('South African Police Uncover Multimillion-Dollar Meth Lab On Farm', 'The South African Police Service (SAPS) and the Directorate for Priority Crime Investigation, known as the Hawks, raided the property.', '\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tEdited by Anjali Thakur  | Monday July 22, 2024                                                        \n                                                        ', 'https://c.ndtvimg.com/2024-07/ct8fl9vg_south-african-police_625x300_22_July_24.jpeg', '2024-07-22 10:49:44.404560')
# 2024-07-22 10:49:44,423 INFO sqlalchemy.engine.Engine INSERT INTO news (title, content, posted_by, image, created_at) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2024-07-22 10:49:44,428 INFO sqlalchemy.engine.Engine [insertmanyvalues 4/17 (ordered; batch not supported)] (None, None, None, None, '2024-07-22 10:49:44.404560')
# 2024-07-22 10:49:44,428 INFO sqlalchemy.engine.Engine INSERT INTO news (title, content, posted_by, image, created_at) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2024-07-22 10:49:44,431 INFO sqlalchemy.engine.Engine [insertmanyvalues 5/17 (ordered; batch not supported)] ("Fresh Terror Attack After Army Chief's Visit Thwarted In Jammu's Rajouri", "The Indian Army repulsed a major attack in Jammu and Kashmir's Rajouri district this morning. A soldier was injured in the predawn attack at an army camp, suggest initial reports.", '\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tWritten by Nazir Masoodi  | Monday July 22, 2024, Rajouri/Jammu                                                        \n                                                        ', 'https://i.ndtvimg.com/i/2018-03/security-forces-kashmir-generic_650x400_51520188882.jpg', '2024-07-22 10:49:44.404560')
# 2024-07-22 10:49:44,431 INFO sqlalchemy.engine.Engine INSERT INTO news (title, content, posted_by, image, created_at) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2024-07-22 10:49:44,431 INFO sqlalchemy.engine.Engine [insertmanyvalues 6/17 (ordered; batch not supported)] ("Not Rohit Sharma Or Virat Kohli: Babar Azam's 'Best Batter' Pick Leaves AB De Villiers Amused", 'Pakistan cricket team captain Babar Azam picked South Africa legend AB De Villiers as the best batter he has played against during his career.', 'NDTV Sports Desk   | Monday July 22, 2024                                                        \n                                                        ', 'https://c.ndtvimg.com/2024-07/91k5o4i8_ab-de-villiers-and-babar-azam_625x300_21_July_24.jpg?im=FitAndFill,algorithm=dnn,width=240,height=180', '2024-07-22 10:49:44.404560')
# 2024-07-22 10:49:44,437 INFO sqlalchemy.engine.Engine INSERT INTO news (title, content, posted_by, image, created_at) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2024-07-22 10:49:44,438 INFO sqlalchemy.engine.Engine [insertmanyvalues 7/17 (ordered; batch not supported)] ('Gautam Gambhir Press Conference: 3 Big Questions India Head Coach Needs To Answer', 'India head coach Gautam Gambhir addresses media for the first time since replacing Rahul Dravid in the role.', 'NDTV Sports Desk   | Monday July 22, 2024                                                        \n                                                        ', 'https://c.ndtvimg.com/2024-07/67hfv6to_gautam-gambhir_640x480_10_July_24.jpg?im=FeatureCrop,algorithm=dnn,width=240,height=180', '2024-07-22 10:49:44.404560')
# 2024-07-22 10:49:44,442 INFO sqlalchemy.engine.Engine INSERT INTO news (title, content, posted_by, image, created_at) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2024-07-22 10:49:44,443 INFO sqlalchemy.engine.Engine [insertmanyvalues 8/17 (ordered; batch not supported)] (None, None, None, None, '2024-07-22 10:49:44.404560')
# 2024-07-22 10:49:44,469 INFO sqlalchemy.engine.Engine INSERT INTO news (title, content, posted_by, image, created_at) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2024-07-22 10:49:44,471 INFO sqlalchemy.engine.Engine [insertmanyvalues 9/17 (ordered; batch not supported)] ('Opinion | A Viksit Bharat Will Need Viksit, Intelligent Villages Too', 'Transforming both the ailing PSU and dormant villages with technology innovations of the "Viksit Village" will make the vision of Viksit Bharat real.', 'Umakant Soni   | Monday July 22, 2024                                                        \n                                                        ', 'https://c.ndtvimg.com/2024-07/kc1vpiog_umakant-soni_120x90_12_July_24.jpg', '2024-07-22 10:49:44.404560')
# 2024-07-22 10:49:44,473 INFO sqlalchemy.engine.Engine INSERT INTO news (title, content, posted_by, image, created_at) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2024-07-22 10:49:44,473 INFO sqlalchemy.engine.Engine [insertmanyvalues 10/17 (ordered; batch not supported)] ('Hours After Biden Drops Out, Kamala Harris Receives $46 Million Donation', 'Democratic fundraising group ActBlue said Sunday evening that it had seen its biggest single-day haul of the 2024 election after US President Joe Biden dropped out and endorsed Vice President Kamala Harris.', 'Agence France-Presse   | Monday July 22, 2024, Washington                                                        \n                                                        ', 'https://c.ndtvimg.com/2024-07/5hctb05g_joe-biden_625x300_22_July_24.jpg?im=FeatureCrop,algorithm=dnn,width=240,height=180', '2024-07-22 10:49:44.404560')
# 2024-07-22 10:49:44,477 INFO sqlalchemy.engine.Engine INSERT INTO news (title, content, posted_by, image, created_at) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2024-07-22 10:49:44,479 INFO sqlalchemy.engine.Engine [insertmanyvalues 11/17 (ordered; batch not supported)] ("India Head Coach Gautam Gambhir's First Press Conference Live Streaming: When and Where To Watch?", "The Indian cricket team's upcoming tour to Sri Lanka will be the first assignment for newly-appointed head coach Gautam Gambhir.", 'NDTV Sports Desk   | Monday July 22, 2024                                                        \n                                                        ', 'https://c.ndtvimg.com/2024-07/tt0ndfr8_gambhir-x_625x300_22_July_24.jpeg', '2024-07-22 10:49:44.404560')
# 2024-07-22 10:49:44,479 INFO sqlalchemy.engine.Engine INSERT INTO news (title, content, posted_by, image, created_at) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2024-07-22 10:49:44,479 INFO sqlalchemy.engine.Engine [insertmanyvalues 12/17 (ordered; batch not supported)] ('West Bengal Primary TET Result 2024 To Be Released Soon', 'WB Primary TET Result 2024: Candidates who have taken the exam can check and download their results by visiting the official site.', '\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tEdited by Lavkesh Singh  | Monday July 22, 2024                                                        \n                                                        ', 'https://i.ndtvimg.com/i/2017-10/exam-result_650x400_51508568554.jpg?im=FeatureCrop,algorithm=dnn,width=240,height=180', '2024-07-22 10:49:44.404560')
# 2024-07-22 10:49:44,479 INFO sqlalchemy.engine.Engine INSERT INTO news (title, content, posted_by, image, created_at) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2024-07-22 10:49:44,486 INFO sqlalchemy.engine.Engine [insertmanyvalues 13/17 (ordered; batch not supported)] ("Watch: Ben Stokes' Priceless Reaction After Spotting His Doppelganger Leaves Everyone In Splits", "Ben Stokes gave a funny reaction after spotting his look-alike in the crowd during his team's second Test match against West Indies at Trent Bridge.", 'NDTV Sports Desk   | Monday July 22, 2024                                                        \n                                                        ', 'https://c.ndtvimg.com/2024-07/9g6gf9b8_ben-stokes-doppelganger-x-englandcricket_625x300_21_July_24.jpg?im=FeatureCrop,algorithm=dnn,width=240,height=180', '2024-07-22 10:49:44.404560')
# 2024-07-22 10:49:44,487 INFO sqlalchemy.engine.Engine INSERT INTO news (title, content, posted_by, image, created_at) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2024-07-22 10:49:44,487 INFO sqlalchemy.engine.Engine [insertmanyvalues 14/17 (ordered; batch not supported)] ('"What Has He Done?": Ex-India Star Questions Ruturaj Gaikwad\'s Snub From Sri Lanka Tour', 'BCCI on July 18 announced the squads for the upcoming Sri Lanka tour. Among the surprise omissions was Ruturaj Gaikwad.', 'NDTV Sports Desk   | Monday July 22, 2024                                                        \n                                                        ', 'https://c.ndtvimg.com/2023-09/j7rett2o_ruturaj-gaikwad-afp_625x300_28_September_23.jpg?im=FeatureCrop,algorithm=dnn,width=240,height=180', '2024-07-22 10:49:44.404560')
# 2024-07-22 10:49:44,491 INFO sqlalchemy.engine.Engine INSERT INTO news (title, content, posted_by, image, created_at) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2024-07-22 10:49:44,493 INFO sqlalchemy.engine.Engine [insertmanyvalues 15/17 (ordered; batch not supported)] ('"Lies, Cheats, Rapes": Indian-Origin Billionaire vs Elon Musk Over Trump', 'Prominent Indian-American businessman Vinod Khosla and billionaire Elon Musk engaged in a war of words this morning after Joe Biden dropped out of the presidential race against Republican rival Donald Trump.', '\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tEdited by Aditi Gautam  | Monday July 22, 2024                                                        \n                                                        ', 'https://c.ndtvimg.com/2024-07/59v82oc8_trump_625x300_22_July_24.jpg?im=FeatureCrop,algorithm=dnn,width=240,height=180', '2024-07-22 10:49:44.404560')
# 2024-07-22 10:49:44,495 INFO sqlalchemy.engine.Engine INSERT INTO news (title, content, posted_by, image, created_at) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2024-07-22 10:49:44,495 INFO sqlalchemy.engine.Engine [insertmanyvalues 16/17 (ordered; batch not supported)] ('"Injustice" Calls Intensify As Hardik Pandya Gets Snubbed For T20I Captaincy', "Hardik Pandya's career has been on a roller-coaster over the last 6 months, with several twists and turns taking place.", 'NDTV Sports Desk   | Monday July 22, 2024                                                        \n                                                        ', 'https://c.ndtvimg.com/2024-07/4gpd7pgo_hardik-pandya-x_625x300_17_July_24.jpeg?im=FeatureCrop,algorithm=dnn,width=240,height=180', '2024-07-22 10:49:44.404560')
# 2024-07-22 10:49:44,499 INFO sqlalchemy.engine.Engine INSERT INTO news (title, content, posted_by, image, created_at) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2024-07-22 10:49:44,499 INFO sqlalchemy.engine.Engine [insertmanyvalues 17/17 (ordered; batch not supported)] ("Kamala Harris, Trailblazer Eyeing America's Last Glass Ceiling", "For years Kamala Harris faced criticism that she was not up to the job of being a heartbeat away from the US presidency. Now, she finds herself feted by Democrats as their best hope to stop Donald Trump's comeback.", 'Agence France-Presse   | Monday July 22, 2024, Washington                                                        \n                                                        ', 'https://c.ndtvimg.com/2024-07/16tsc1a8_kamala-harris-afp_625x300_22_July_24.jpg?im=FeatureCrop,algorithm=dnn,width=240,height=180', '2024-07-22 10:49:44.404560')
# 2024-07-22 10:49:44,502 INFO sqlalchemy.engine.Engine COMMIT

# %%
out[0]
# Out:
# {'image': 'https://c.ndtvimg.com/2024-07/2pvlbrmo_gambhir_625x300_22_July_24.jpg?im=FitAndFill,algorithm=dnn,width=240,height=180',
#  'title': 'Gautam Gambhir Press Conference Live Updates: "My Relationship With Virat Not For TRPs"',
#  'post': 'NDTV Sports Desk   | Monday July 22, 2024                                                        \n                                                        ',
#  'content': 'Gautam Gambhir Press Conference Live: As the head coach of the Indian team, Gautam Gambhir speaks to media in Mumbai, with chief select Ajit Agarkar beside him.'}

# %%
import pandas as pd    # values ko firse read krna

pd.read_sql('news',engine)
# Out:
# 2024-07-22 10:44:21,727 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-22 10:44:21,732 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("news")
# 2024-07-22 10:44:21,734 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-22 10:44:21,734 INFO sqlalchemy.engine.Engine SELECT name FROM sqlite_master WHERE type='table' AND name NOT LIKE 'sqlite~_%' ESCAPE '~' ORDER BY name
# 2024-07-22 10:44:21,734 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-22 10:44:21,744 INFO sqlalchemy.engine.Engine SELECT name FROM sqlite_master WHERE type='view' AND name NOT LIKE 'sqlite~_%' ESCAPE '~' ORDER BY name
# 2024-07-22 10:44:21,744 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-22 10:44:21,749 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("news")
# 2024-07-22 10:44:21,751 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-22 10:44:21,754 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2024-07-22 10:44:21,754 INFO sqlalchemy.engine.Engine [raw sql] ('news',)
# 2024-07-22 10:44:21,787 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("news")
# 2024-07-22 10:44:21,787 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-22 10:44:21,798 INFO sqlalchemy.engine.Engine PRAGMA temp.foreign_key_list("news")
# 2024-07-22 10:44:21,798 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-22 10:44:21,798 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2024-07-22 10:44:21,798 INFO sqlalchemy.engine.Engine [raw sql] ('news',)
# 2024-07-22 10:44:21,803 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("news")
# 2024-07-22 10:44:21,803 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-22 10:44:21,803 INFO sqlalchemy.engine.Engine PRAGMA temp.index_list("news")
# 2024-07-22 10:44:21,803 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-22 10:44:21,811 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("news")
# 2024-07-22 10:44:21,811 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-22 10:44:21,815 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("news")
# 2024-07-22 10:44:21,824 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-22 10:44:21,825 INFO sqlalchemy.engine.Engine PRAGMA temp.index_list("news")
# 2024-07-22 10:44:21,829 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-22 10:44:21,829 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("news")
# 2024-07-22 10:44:21,829 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-22 10:44:21,829 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2024-07-22 10:44:21,837 INFO sqlalchemy.engine.Engine [raw sql] ('news',)
# 2024-07-22 10:44:21,841 INFO sqlalchemy.engine.Engine SELECT news.id, news.title, news.content, news.posted_by, news.image, news.created_at
# FROM news
# 2024-07-22 10:44:21,845 INFO sqlalchemy.engine.Engine [generated in 0.00290s] ()
# 2024-07-22 10:44:21,862 INFO sqlalchemy.engine.Engine ROLLBACK
#     id                                              title  \
# 0    1  Gautam Gambhir Press Conference Live Updates: ...
# 1    2  Byju's Founder Faces Reckoning As Company's Va...
# 2    3  South African Police Uncover Multimillion-Doll...
# 3    4                                               None
# 4    5  Fresh Terror Attack After Army Chief's Visit T...
# 5    6  Not Rohit Sharma Or Virat Kohli: Babar Azam's ...
# 6    7  Gautam Gambhir Press Conference: 3 Big Questio...
# 7    8                                               None
# 8    9  Opinion | A Viksit Bharat Will Need Viksit, In...
# 9   10  Hours After Biden Drops Out, Kamala Harris Rec...
# 10  11  India Head Coach Gautam Gambhir's First Press ...
# 11  12  West Bengal Primary TET Result 2024 To Be Rele...
# 12  13  Watch: Ben Stokes' Priceless Reaction After Sp...
# 13  14  "What Has He Done?": Ex-India Star Questions R...
# 14  15  "Lies, Cheats, Rapes": Indian-Origin Billionai...
# 15  16  "Injustice" Calls Intensify As Hardik Pandya G...
# 16  17  Kamala Harris, Trailblazer Eyeing America's La...
#
#                                               content  \
# 0   Gautam Gambhir Press Conference Live: As the h...
# 1   Byju Raveendran, the mathematics whiz who soar...
# 2   The South African Police Service (SAPS) and th...
# 3                                                None
# 4   The Indian Army repulsed a major attack in Jam...
# 5   Pakistan cricket team captain Babar Azam picke...
# 6   India head coach Gautam Gambhir addresses medi...
# 7                                                None
# 8   Transforming both the ailing PSU and dormant v...
# 9   Democratic fundraising group ActBlue said Sund...
# 10  The Indian cricket team's upcoming tour to Sri...
# 11  WB Primary TET Result 2024: Candidates who hav...
# 12  Ben Stokes gave a funny reaction after spottin...
# 13  BCCI on July 18 announced the squads for the u...
# 14  Prominent Indian-American businessman Vinod Kh...
# 15  Hardik Pandya's career has been on a roller-co...
# 16  For years Kamala Harris faced criticism that s...
#
#                                             posted_by  \
# 0   NDTV Sports Desk   | Monday July 22, 2024     ...
# 1   Reuters   | Monday July 22, 2024, New Delhi   ...
# 2   \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tEdited by Anja...
# 3                                                None
# 4   \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tWritten by Naz...
# 5   NDTV Sports Desk   | Monday July 22, 2024     ...
# 6   NDTV Sports Desk   | Monday July 22, 2024     ...
# 7                                                None
# 8   Umakant Soni   | Monday July 22, 2024         ...
# 9   Agence France-Presse   | Monday July 22, 2024,...
# 10  NDTV Sports Desk   | Monday July 22, 2024     ...
# 11  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tEdited by Lavk...
# 12  NDTV Sports Desk   | Monday July 22, 2024     ...
# 13  NDTV Sports Desk   | Monday July 22, 2024     ...
# 14  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tEdited by Adit...
# 15  NDTV Sports Desk   | Monday July 22, 2024     ...
# 16  Agence France-Presse   | Monday July 22, 2024,...
#
#                                                 image  \
# 0   https://c.ndtvimg.com/2024-07/2pvlbrmo_gambhir...
# 1   https://c.ndtvimg.com/2024-07/6h8u1do8_byju-ra...
# 2   https://c.ndtvimg.com/2024-07/ct8fl9vg_south-a...
# 3                                                None
# 4   https://i.ndtvimg.com/i/2018-03/security-force...
# 5   https://c.ndtvimg.com/2024-07/91k5o4i8_ab-de-v...
# 6   https://c.ndtvimg.com/2024-07/67hfv6to_gautam-...
# 7                                                None
# 8   https://c.ndtvimg.com/2024-07/kc1vpiog_umakant...
# 9   https://c.ndtvimg.com/2024-07/5hctb05g_joe-bid...
# 10  https://c.ndtvimg.com/2024-07/tt0ndfr8_gambhir...
# 11  https://i.ndtvimg.com/i/2017-10/exam-result_65...
# 12  https://c.ndtvimg.com/2024-07/9g6gf9b8_ben-sto...
# 13  https://c.ndtvimg.com/2023-09/j7rett2o_ruturaj...
# 14  https://c.ndtvimg.com/2024-07/59v82oc8_trump_6...
# 15  https://c.ndtvimg.com/2024-07/4gpd7pgo_hardik-...
# 16  https://c.ndtvimg.com/2024-07/16tsc1a8_kamala-...
#
#                    created_at
# 0  2024-07-22 10:43:17.953510
# 1  2024-07-22 10:43:17.953510
# 2  2024-07-22 10:43:17.953510
# 3  2024-07-22 10:43:17.953510
# 4  2024-07-22 10:43:17.953510
# 5  2024-07-22 10:43:17.953510
# 6  2024-07-22 10:43:17.953510
# 7  2024-07-22 10:43:17.953510
# 8  2024-07-22 10:43:17.953510
# 9  2024-07-22 10:43:17.953510
# 10 2024-07-22 10:43:17.953510
# 11 2024-07-22 10:43:17.953510
# 12 2024-07-22 10:43:17.953510
# 13 2024-07-22 10:43:17.953510
# 14 2024-07-22 10:43:17.953510
# 15 2024-07-22 10:43:17.953510
# 16 2024-07-22 10:43:17.953510

# %%
news_df
